# %%
pilotdata <- read.csv(file = 'data/PilotDataFile.csv', stringsAsFactors = FALSE)
head(pilotdata)
# Out:
#   ï..blockcode blocknum trialnum trialcode     sound.monosylsound.currentitem
# 1 consent      1        1        consent       Ba sound recording.wav
# 2 myblock      2        1        mytrial       Ba sound recording.wav
# 3 myblock      2        2        mytrial       Ba sound recording.wav
# 4 myblock      2        3        mytrial       Ba sound recording.wav
# 5 Practice     3        1        calibration   Ba sound recording.wav
# 6 Practice     3        2        Practicetrial Ba sound recording.wav
#   response latency subject
# 1 57       5167    1
# 2 57       2949    1
# 3 57       3166    1
# 4 57       3175    1
# 5 57       3405    1
# 6 57       2733    1
# Warning message:
# "package 'wesanderson' is in use and will not be installed"

# %%
#Taken from Ariel's code
shhh <- suppressPackageStartupMessages # stops annoying warnings when loading libraries
library(tidyr)
library(plyr)
library(dplyr)
library(ggplot2)
library(gridExtra)
library(MASS)
library(Matrix)
library(reshape2)
library(RColorBrewer)
library(DescTools)
library(grid)
library(wesanderson)
# Out:
# Error in library(DescTools): there is no package called 'DescTools'
# Traceback:
#
# 1. library(DescTools)

# %%
pilotdata$response <- ifelse(pilotdata$response == 'zerobutton', '0', pilotdata$response)
pilotdata$response <- ifelse(pilotdata$response == 'onebutton', '1', pilotdata$response)
pilotdata$response <- ifelse(pilotdata$response == 'twobutton', '2', pilotdata$response)
pilotdata$response <- ifelse(pilotdata$response == 'threebutton', '3', pilotdata$response)
pilotdata$response <- ifelse(pilotdata$response == 'fourbutton', '4', pilotdata$response)
pilotdata$response <- ifelse(pilotdata$response == 'fivebutton', '5', pilotdata$response)
pilotdata$response <- ifelse(pilotdata$response == 'sixbutton', '6', pilotdata$response)
pilotdata$response <- ifelse(pilotdata$response == 'sevenbutton', '7', pilotdata$response)
pilotdata$response <- ifelse(pilotdata$response == 'centrebutton', '0.1', pilotdata$response)
pilotdata$response <- ifelse(pilotdata$response == '57', '0.57', pilotdata$response)
pilotdata$response <- as.numeric(as.character(pilotdata$response))
pilotdata$response
# Out:
#    [1] 0.57 0.57 0.57 0.57 0.57 0.57 0.57 0.57 0.57 0.57 0.57 0.57 0.57 0.57
#   [15] 0.57 0.57 0.57 0.57 7.00 0.10 1.00 0.10 0.57 5.00 0.10 0.00 0.10 7.00
#   [29] 0.10 5.00 0.10 5.00 0.10 1.00 0.10 4.00 0.10 1.00 0.10 6.00 0.10 3.00
#   [43] 0.10 0.00 0.10 6.00 0.10 5.00 0.10 2.00 0.10 5.00 0.10 5.00 0.10 3.00
#   [57] 0.10 1.00 0.10 0.00 0.10 5.00 0.10 3.00 0.10 0.00 0.10 2.00 0.10 7.00
#   [71] 0.10 7.00 0.10 0.00 0.10 0.00 0.10 1.00 0.10 1.00 0.10 0.00 0.10 5.00
#   [85] 0.10 7.00 0.10 7.00 0.10 3.00 0.10 5.00 0.10 0.00 0.10 0.00 0.10 6.00
#   [99] 0.10 7.00 0.10 5.00 0.10 4.00 0.10 5.00 0.10 0.00 0.10 2.00 0.10 6.00
#  [113] 0.10 3.00 0.10 7.00 0.10 7.00 0.10 0.00 0.10 0.00 0.10 0.00 0.10 6.00
#  [827] 0.10 3.00 0.10 2.00 0.10 5.00 0.10 5.00 0.10 0.00 0.10 5.00 0.10 5.00
#  [841] 0.10 7.00 0.10 2.00 0.10 7.00 0.10 3.00 0.10 3.00 0.10 7.00 0.10 0.00
#  [855] 0.10 7.00 0.10 7.00 0.10 7.00 0.10 1.00 0.10 5.00 0.10 3.00 0.10 1.00
#  [869] 0.10 1.00 0.10 1.00 0.10 7.00 0.10 3.00 0.10 3.00 0.10 1.00 0.10 5.00
#  [883] 0.10 7.00 0.10 1.00 0.10 5.00 0.10 5.00 0.10 2.00 0.10 4.00 0.10 3.00
#  [897] 0.10 0.00 0.10 5.00 0.10 5.00 0.10 4.00 0.10 0.00 0.10 4.00 0.10 7.00
#  [911] 0.10 1.00 0.10 6.00 0.10 6.00 0.10 1.00 0.10 1.00 0.10 3.00 0.10 1.00
#  [925] 0.10 2.00 0.10 2.00 0.10 6.00 0.10 3.00 0.10 3.00 0.10 4.00 0.10 1.00
#  [939] 0.10 4.00 0.10 5.00 0.10 2.00 0.10 7.00 0.10 2.00 0.10 3.00 0.10 7.00
#  [953] 0.10 4.00 0.10 4.00 0.10 3.00 0.10 7.00 0.10 3.00 0.10 4.00 0.10 6.00
#  [967] 0.10 1.00 0.10 1.00 0.10 5.00 0.10 5.00 0.10 3.00 0.10 3.00 0.10 2.00
#  [981] 0.10 1.00 0.10 6.00 0.10 1.00 0.10 0.00 0.10 1.00 0.10 4.00 0.10 3.00
#  [995] 0.10 4.00 0.10 2.00 0.10 1.00 0.10 2.00 0.10 4.00 0.10 2.00 0.10 7.00
# [1009] 0.10 3.00 0.10

# %%
#Taken from Ariel's code
# rainbowcloud theme for plotting, stolen from: 
# https://micahallen.org/2018/03/15/introducing-raincloud-plots/?utm_campaign=News&utm_medium=Community&utm_source=DataCamp.com




dataanaly <- subset(pilotdata, blocknum == 4 & response != "0.1" & subject == 1 & trialcode != "catchtrial" & trialcode != "centremouse") #specifying specific portion of data to be analysed
q <- qplot(trialcode, sound.monosylsound.currentitem, data=dataanaly, color = as.factor(response))
q  + scale_color_brewer(palette = "Spectral") +
            scale_fill_brewer(palette = "Spectral") + 
            theme(
text = element_text(size = 10),
axis.title.x = element_text(size = 16),
axis.title.y = element_text(size = 16),
axis.text = element_text(size = 10),
axis.text.x = element_text(angle = 90, vjust = 0.5),
legend.title=element_text(size=10),
legend.text=element_text(size=10),
legend.position = "right",
plot.title = element_text(lineheight=.8, face="bold", size = 16),
panel.border = element_blank(),
panel.grid.minor = element_blank(),
panel.grid.major = element_blank(),
axis.line.x = element_line(colour = 'black', size=0.5, linetype='solid'),
axis.line.y = element_line(colour = 'black', size=0.5, linetype='solid')) + 
geom_point(shape = 15, size = 9) + coord_equal() + labs(y= "Second sound heard", x = "First Sound Heard", title = "Subject 1 Plot")


q


# 0 = most similar 7 = most dissimilar
# Out:
# plot without title
# plot without title

# %%
dataanaly <- subset(pilotdata, blocknum == 4 & response != "0.1" & trialcode != "catchtrial" & trialcode != "centremouse")
day <- data.frame(dataanaly$trialcode, dataanaly$sound.monosylsound.currentitem)

# Need to count the number of times that each combo appears and plot it into matrix like the one seen above
# To do this need to store pairwise combo and frequency in dataframe then plot using qplot
da<-table(apply(day,1,function(x) paste(sort(x),collapse='-')))
df<-data.frame(da)


cols <- c('dataanaly.trialcode', 'dataanaly.sound.monosylsound.currentitem')

day$x <- apply(day[ , cols], 1, paste, collapse = "-")



daytable<-table(day$x)

dayframe <- data.frame(daytable)
d<-separate(data = dayframe, col = Var1, into = c("left", "right"), sep = "-")
                
checkq <- qplot(left, right, data=d, color = as.factor(Freq))
checkq +   scale_color_brewer(palette = "Spectral") +
            scale_fill_brewer(palette = "Spectral") +
            theme(
text = element_text(size = 10),
axis.title.x = element_text(size = 16),
axis.title.y = element_text(size = 16),
axis.text = element_text(size = 10),
axis.text.x = element_text(angle = 90, vjust = 0.5),
legend.title=element_text(size=10),
legend.text=element_text(size=10),
legend.position = "right",
plot.title = element_text(lineheight=.8, face="bold", size = 16),
panel.border = element_blank(),
panel.grid.minor = element_blank(),
panel.grid.major = element_blank(),
axis.line.x = element_line(colour = 'black', size=0.5, linetype='solid'),
axis.line.y = element_line(colour = 'black', size=0.5, linetype='solid')) + 
geom_point(shape = 15, size = 9) + coord_equal() + labs(y= "Second sound heard", x = "First Sound Heard", title = "All Subjects Plot", color = "Number of Trials")
# Out:
# plot without title

# %%
dataanaly <- subset(pilotdata, blocknum == 4 & response != "0.1" & subject == 2 & trialcode != "catchtrial")
day <- data.frame(dataanaly$trialcode, dataanaly$sound.monosylsound.currentitem)
                             
# Need to count the number of times that each combo appears and plot it into matrix like the one seen above
# To do this need to store pairwise combo and frequency in dataframe then plot using qplot
da<-table(apply(day,1,function(x) paste(sort(x),collapse='-')))

d<-separate(data = df, col = Var1, into = c("left", "right"), sep = "-")
# Out:
#        Ba backward.wav-Babackwardsound                Ba backward.wav-Basound
#                                      1                                      1
#            Ba backward.wav-centremouse        Ba backward.wav-Dabackwardsound
#                                     12                                      1
#                Ba backward.wav-Dasound        Ba backward.wav-Gabackwardsound
#                                      1                                      1
#                Ba backward.wav-Gasound        Ba backward.wav-Kabackwardsound
#                                      1                                      1
#                Ba backward.wav-Kasound        Ba backward.wav-Pabackwardsound
#                                      1                                      1
#                Ba backward.wav-Pasound        Ba backward.wav-Tabackwardsound
#                                      1                                      1
#                Ba backward.wav-Tasound Ba sound recording.wav-Babackwardsound
#                                      1                                      1
#         Ba sound recording.wav-Basound     Ba sound recording.wav-centremouse
#                                      1                                     13
# Ba sound recording.wav-Dabackwardsound         Ba sound recording.wav-Dasound
#                                      1                                      1
# Ba sound recording.wav-Gabackwardsound         Ba sound recording.wav-Gasound
#                                      1                                      1
# Ba sound recording.wav-Kabackwardsound         Ba sound recording.wav-Kasound
#                                      1                                      1
# Ba sound recording.wav-Pabackwardsound         Ba sound recording.wav-Pasound
#                                      1                                      1
# Ba sound recording.wav-Tabackwardsound         Ba sound recording.wav-Tasound
#                                      1                                      1
#        Babackwardsound-Da backward.wav Babackwardsound-Da sound recording.wav
#                                      1                                      1
#        Babackwardsound-Ga backward.wav Babackwardsound-Ga sound recording.wav
#                                      1                                      1
#        Babackwardsound-Ka backward.wav Babackwardsound-Ka sound recording.wav
#                                      1                                      1
#        Babackwardsound-Pa backward.wav Babackwardsound-Pa sound recording.wav
#                                      1                                      1
#        Babackwardsound-Ta backward.wav Babackwardsound-Ta sound recording.wav
#                                      1                                      1
#                Basound-Da backward.wav         Basound-Da sound recording.wav
#                                      1                                      1
#                Basound-Ga backward.wav         Basound-Ga sound recording.wav
#                                      1                                      1
#                Basound-Ka backward.wav         Basound-Ka sound recording.wav
#                                      1                                      1
#                Basound-Pa backward.wav         Basound-Pa sound recording.wav
#                                      1                                      1
#                Basound-Ta backward.wav         Basound-Ta sound recording.wav
#                                      1                                      1
#            centremouse-Da backward.wav     centremouse-Da sound recording.wav
#                                     13                                     13
#            centremouse-Ga backward.wav     centremouse-Ga sound recording.wav
#                                     13                                     13
#            centremouse-Ka backward.wav     centremouse-Ka sound recording.wav
#                                     12                                     14
#            centremouse-Pa backward.wav     centremouse-Pa sound recording.wav
#                                     13                                     13
#            centremouse-Ta backward.wav     centremouse-Ta sound recording.wav
#                                     13                                     15
#        Da backward.wav-Dabackwardsound                Da backward.wav-Dasound
#                                      1                                      1
#        Da backward.wav-Gabackwardsound                Da backward.wav-Gasound
#                                      1                                      1
#        Da backward.wav-Kabackwardsound                Da backward.wav-Kasound
#                                      1                                      1
#        Da backward.wav-Pabackwardsound                Da backward.wav-Pasound
#                                      1                                      1
#        Da backward.wav-Tabackwardsound                Da backward.wav-Tasound
#                                      1                                      1
# Da sound recording.wav-Dabackwardsound         Da sound recording.wav-Dasound
#                                      1                                      1
# Da sound recording.wav-Gabackwardsound         Da sound recording.wav-Gasound
#                                      1                                      1
# Da sound recording.wav-Kabackwardsound         Da sound recording.wav-Kasound
#                                      1                                      1
# Da sound recording.wav-Pabackwardsound         Da sound recording.wav-Pasound
#                                      1                                      1
# Da sound recording.wav-Tabackwardsound         Da sound recording.wav-Tasound
#                                      1                                      1
#        Dabackwardsound-Ga backward.wav Dabackwardsound-Ga sound recording.wav
#                                      1                                      1
#        Dabackwardsound-Ka backward.wav Dabackwardsound-Ka sound recording.wav
#                                      1                                      1
#        Dabackwardsound-Pa backward.wav Dabackwardsound-Pa sound recording.wav
#                                      1                                      1
#        Dabackwardsound-Ta backward.wav Dabackwardsound-Ta sound recording.wav
#                                      1                                      1
#                Dasound-Ga backward.wav         Dasound-Ga sound recording.wav
#                                      1                                      1
#                Dasound-Ka backward.wav         Dasound-Ka sound recording.wav
#                                      1                                      1
#                Dasound-Pa backward.wav         Dasound-Pa sound recording.wav
#                                      1                                      1
#                Dasound-Ta backward.wav         Dasound-Ta sound recording.wav
#                                      1                                      1
#        Ga backward.wav-Gabackwardsound                Ga backward.wav-Gasound
#                                      1                                      1
#        Ga backward.wav-Kabackwardsound                Ga backward.wav-Kasound
#                                      1                                      1
#        Ga backward.wav-Pabackwardsound                Ga backward.wav-Pasound
#                                      1                                      1
#        Ga backward.wav-Tabackwardsound                Ga backward.wav-Tasound
#                                      1                                      1
# Ga sound recording.wav-Gabackwardsound         Ga sound recording.wav-Gasound
#                                      1                                      1
# Ga sound recording.wav-Kabackwardsound         Ga sound recording.wav-Kasound
#                                      1                                      1
# Ga sound recording.wav-Pabackwardsound         Ga sound recording.wav-Pasound
#                                      1                                      1
# Ga sound recording.wav-Tabackwardsound         Ga sound recording.wav-Tasound
#                                      1                                      1
#        Gabackwardsound-Ka backward.wav Gabackwardsound-Ka sound recording.wav
#                                      1                                      1
#        Gabackwardsound-Pa backward.wav Gabackwardsound-Pa sound recording.wav
#                                      1                                      1
#        Gabackwardsound-Ta backward.wav Gabackwardsound-Ta sound recording.wav
#                                      1                                      1
#                Gasound-Ka backward.wav         Gasound-Ka sound recording.wav
#                                      1                                      1
#                Gasound-Pa backward.wav         Gasound-Pa sound recording.wav
#                                      1                                      1
#                Gasound-Ta backward.wav         Gasound-Ta sound recording.wav
#                                      1                                      1
#        Ka backward.wav-Kabackwardsound                Ka backward.wav-Kasound
#                                      1                                      1
#        Ka backward.wav-Pabackwardsound                Ka backward.wav-Pasound
#                                      1                                      1
#        Ka backward.wav-Tabackwardsound                Ka backward.wav-Tasound
#                                      1                                      1
# Ka sound recording.wav-Kabackwardsound         Ka sound recording.wav-Kasound
#                                      1                                      1
# Ka sound recording.wav-Pabackwardsound         Ka sound recording.wav-Pasound
#                                      1                                      1
# Ka sound recording.wav-Tabackwardsound         Ka sound recording.wav-Tasound
#                                      1                                      1
#        Kabackwardsound-Pa backward.wav Kabackwardsound-Pa sound recording.wav
#                                      1                                      1
#        Kabackwardsound-Ta backward.wav Kabackwardsound-Ta sound recording.wav
#                                      1                                      1
#                Kasound-Pa backward.wav         Kasound-Pa sound recording.wav
#                                      1                                      1
#                Kasound-Ta backward.wav         Kasound-Ta sound recording.wav
#                                      1                                      1
#        Pa backward.wav-Pabackwardsound                Pa backward.wav-Pasound
#                                      1                                      1
#        Pa backward.wav-Tabackwardsound                Pa backward.wav-Tasound
#                                      1                                      1
# Pa sound recording.wav-Pabackwardsound         Pa sound recording.wav-Pasound
#                                      1                                      1
# Pa sound recording.wav-Tabackwardsound         Pa sound recording.wav-Tasound
#                                      1                                      1
#        Pabackwardsound-Ta backward.wav Pabackwardsound-Ta sound recording.wav
#                                      1                                      1
#                Pasound-Ta backward.wav         Pasound-Ta sound recording.wav
#                                      1                                      1
#        Ta backward.wav-Tabackwardsound                Ta backward.wav-Tasound
#                                      1                                      1
# Ta sound recording.wav-Tabackwardsound         Ta sound recording.wav-Tasound
#                                      1                                      1

# %%
# making a matrix symmetric. Stolen from dclone: https://rdrr.io/github/datacloning/dclone/src/R/make.symmetric.R
make.symmetric <-
function(x)
{
    if (dim(x)[1] != dim(x)[2])
        stop("'x' is not sqare matrix")
    rval <- t(x)
    m <- (x[lower.tri(x)] + rval[lower.tri(rval)]) / 2
    rval[lower.tri(rval)] <- m
    rval <- t(rval)
    rval[lower.tri(rval)] <- m
    rval
}

# %%
# turn a dataset into a matrix
df2mat <- function(datadf,eccentricity1,eccentricity2,dependent='color'){
    
    # select only the eccentricities we want to keep, e.g. (foveal, foveal)
    datadf = subset(datadf, Circle_1 == eccentricity1)
    datadf = subset(datadf, Circle_2 == eccentricity2)
    
    if(dependent == 'position'){ # using stimulus location as a negative control
        # aggregate over the remaining columns of interest
        nmdsdata <- aggregate(datadf, by = list(datadf$bin1, datadf$bin2),FUN=mean)
        nmdsdata$bin1 <- nmdsdata$Group.1
        nmdsdata$bin2 <- nmdsdata$Group.2
        
        nmdsdata = subset(nmdsdata, select = c("bin1","bin2","p_confidence"))  # get rid of unnecessary columns
        nmdsmatrix <- spread(nmdsdata, bin1, p_confidence)
    } else { # color as per normal
        # aggregate over the remaining columns of interest
        nmdsdata <- aggregate(datadf, by = list(datadf$Color_1, datadf$Color_2),FUN=mean)
        nmdsdata$Color_1 <- nmdsdata$Group.1
        nmdsdata$Color_2 <- nmdsdata$Group.2
        
        nmdsdata = subset(nmdsdata, select = c("Color_1","Color_2","p_confidence"))  # get rid of unnecessary columns
        nmdsmatrix <- spread(nmdsdata, Color_1, p_confidence)
    }
    
    # convert the dataframe to a matrix
    nmdsmatrix <- data.matrix(nmdsmatrix)
    nmdsmatrix <- nmdsmatrix[,-1] # get rid of the labels in the first column, it messes up the code
    
    # having 0 dissimilarity between identical objects messes up the algorithm
    # changing the 0 values to an arbitrarily small value, but this is not a good long-term solution
    # need to find a better way of doing this
    nmdsmatrix[nmdsmatrix == 0] <- 0.01
    
    
    nmdsmatrix <- make.symmetric(nmdsmatrix) # averaging over Color_1 vs. Color_2 & Color_2 vs. Color_1    
    return(nmdsmatrix)
}

# %%
# convert a standard matrix to a distance matrix
mat2dist <- function(mat){
    
    return(distmat <- as.dist(mat))
}

# %%
# find the nmds fit for a dataset
nmdsfit <- function(distmatrix){
      
    fit <- isoMDS(distmatrix,k=2, maxit=100)
    return(fit)
}

# %%
# plot the nmds fit
nmdsplot <- function(fit, colors, abcolors, eccentricity1, eccentricity2){
    
    # get labels
    
    # change the nmdsfit back to a dataframe
    nmdsdf <- as.data.frame(fit)
    
    plot <-     ggplot(nmdsdf, aes(x = points.1, y = points.2, color=colors, fill=colors)) + geom_point(size =10) + 
                scale_colour_manual(values = abcolors) + scale_fill_manual(values = abcolors) + 
                xlab("Dimension 1") + ylab("Dimension 2") + 
                ggtitle(paste(e2l(eccentricity1),e2l(eccentricity2),'Non-metric MDS',sep=' - '))
    return(plot)
}

# %%
# find the cmds fit for a dataset
cmdsfit <- function(distmatrix){
    
    fit <- cmdscale(distmatrix,k=2)
    return(fit)
}

# %%
# plot the cmds fit
cmdsplot <- function(fit, colors, abcolors, eccentricity1, eccentricity2){
    
    # get labels
    
    # change the nmdsfit back to a dataframe
    nmdsdf <- as.data.frame(fit)
    
    plot <-     ggplot(nmdsdf, aes(x = V1, y = V2, color=colors, fill=colors)) + geom_point(size =10) + 
                scale_colour_manual(values = abcolors) + scale_fill_manual(values = abcolors) + 
                xlab("Dimension 1") + ylab("Dimension 2") + 
                ggtitle(paste(e2l(eccentricity1),e2l(eccentricity2),'Classical MDS',sep=' - '))
    return(plot)
}

# %%
# similarity judgement histogram
simhistplot <- function(datadf){
    
   plot <- ggplot(datadf, aes(x = p_confidence)) + geom_bar(aes(y = ..prop..)) +
    scale_x_discrete(limits=c(0,1,2,3,4,5,6,7), name = 'Dissimilarity') +
    ylab('Frequency') + ylim(0,0.8)
    return(plot)
}

simhistplot_summary <- function(datadf){
    
    datadf$subject <- as.character(datadf$subject) # necessary for visualisation
    
    plot <- ggplot(datadf, aes(x = p_confidence)) + 
    geom_line(stat='count',aes(y = ..prop..,group = subject),color='#CC9933') +
    geom_line(stat='count',aes(y = ..prop..),size=1.5) +
    scale_x_discrete(limits=c(0,1,2,3,4,5,6,7), name = 'Dissimilarity') +
    ylab('Frequency') + ylim(0,0.8)
    return(plot)
    
}

# %%
# reaction time for each similarity
rsplot <- function(datadf){
    
    plot <- ggplot(datadf, aes(x= p_confidence, y=response_time)) + 
    stat_summary(fun.y = mean, geom = "bar") + 
    stat_summary(fun.data = mean_se, geom = "errorbar", size =0.5, aes(width=0.5)) +
    scale_x_discrete(limits=c(0,1,2,3,4,5,6,7), name = 'Dissimilarity') + ylab('Reaction Time (ms)') +
    theme(legend.position = "none") +
    ylim(0,4000) # anyone taking more than 4 seconds has probably mindwandered
    
    return(plot)
}

rsplot_summary <- function(datadf){
    
    datadf$subject <- as.character(datadf$subject) # necessary for visualisation
    
    
    
    plot <- ggplot(datadf, aes(x= p_confidence, y=response_time,group = subject, color = subject)) + 
    stat_summary(fun.y = mean, geom = "line", size=0.8) + 
    #stat_summary(fun.data = mean_se, geom = "errorbar", size =0.5, aes(width=0.5)) +
    scale_x_discrete(limits=c(0,1,2,3,4,5,6,7), name = 'Dissimilarity') + ylab('Mean Reaction Time (ms)') +
    theme(legend.position = "none") +
    ylim(0,4000) # anyone taking more than 4 seconds has probably mindwandered 
    
    return(plot)
    
}

# %%
# reaction time raincloud plot
rsplot_raincloud <- function(datadf,xtype='linear'){
    
    datadf$subject <- as.character(datadf$subject) # necessary for visualisation  
    datadf$p_confidence <- as.character(datadf$p_confidence) # necessary for visualisation
    
    ylabtext = 'Reaction Time (ms)'
    
    plot <- ggplot(datadf, aes(y = response_time, x = p_confidence, fill = p_confidence)) +
            geom_flat_violin(position = position_nudge(x = .2, y = 0), alpha = .8) +
            geom_point(aes(y = response_time, color = p_confidence),
                   position = position_jitter(width = .15), size = .5, alpha = 0.8) +
            geom_boxplot(width = .1, guides = FALSE, outlier.shape = NA, alpha = 0.5) +
            expand_limits(x = 5.25) +
            guides(fill = FALSE) +
            guides(color = FALSE) +
            scale_color_brewer(palette = "Spectral") +
            scale_fill_brewer(palette = "Spectral") +
            xlab('Dissimilarity') + ylab("Reaction Time (ms)")
            # coord_flip() +
            theme_bw() +
            raincloud_theme
    
    if(xtype == 'log'){
        plot <- plot + scale_y_continuous(trans='log10')
    } else{
        plot <- plot + ylim(0,5000)
    }
    
    return(plot)
}

# %%
# subject info
sumplot <- function(datadf){
    
    # change ms to s, add the delay for each trial
    datadf$response_time <- ((datadf$response_time + 0.125*nrow(datadf)) / 1000)
    
    plot <- ggplot(datadf, aes(x=subject, y = response_time)) + 
    stat_summary(fun.y = sum, geom = "bar") + ylim(0,1000) +
    ylab('Response Time Total') + theme(axis.title.x=element_blank(), axis.text.x = element_text(size=20))
    
    return(plot)
}
